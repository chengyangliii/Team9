# %%
import pandas as pd
import numpy as np

# %%
csv_source_file_path = 'csv_source_files/'
source_date = pd.read_csv(csv_source_file_path + 'calendar.csv')

source_date['date'] = pd.to_datetime(source_date['date']).dt.strftime('%Y-%m-%d')
source_date = source_date[ (source_date['date']>'2018-12-31') & (source_date['date']<'2030-01-01') ]

# %%
source_date.head()
# Out:
#        sasdate  date_key        word_date        date  year  quarter  month  \
# 21549    21550     10119  January 1, 2019  2019-01-01  2019        1      1
# 21550    21551     10219  January 2, 2019  2019-01-02  2019        1      1
# 21551    21552     10319  January 3, 2019  2019-01-03  2019        1      1
# 21552    21553     10419  January 4, 2019  2019-01-04  2019        1      1
# 21553    21554     10519  January 5, 2019  2019-01-05  2019        1      1
#
#        day_of_month  week day_of_week  weekday month_and_year  holiday  \
# 21549             1     0         Tue        3        JAN1960  NEWYEAR
# 21550             2     0         Wed        4        JAN1960      NaN
# 21551             3     0         Thu        5        JAN1960      NaN
# 21552             4     0         Fri        6        JAN1960      NaN
# 21553             5     0         Sat        7        JAN1960      NaN
#
#       timezone_id   timezone  timezone_offset
# 21549   ETC/GMT+7  GMT-07:00           -25200
# 21550   ETC/GMT+7  GMT-07:00           -25200
# 21551   ETC/GMT+7  GMT-07:00           -25200
# 21552   ETC/GMT+7  GMT-07:00           -25200
# 21553   ETC/GMT+7  GMT-07:00           -25200

# %%
source_date.tail()
# Out:
#        sasdate  date_key           word_date        date  year  quarter  \
# 23995    23996     91225  September 12, 2025  2025-09-12  2025        3
# 23996    23997     91325  September 13, 2025  2025-09-13  2025        3
# 23997    23998     91425  September 14, 2025  2025-09-14  2025        3
# 23998    23999     91525  September 15, 2025  2025-09-15  2025        3
# 23999    24000     91625  September 16, 2025  2025-09-16  2025        3
#
#        month  day_of_month  week day_of_week  weekday month_and_year holiday  \
# 23995      9            12    36         Fri        6        JAN1960     NaN
# 23996      9            13    36         Sat        7        JAN1960     NaN
# 23997      9            14    37         Sun        1        JAN1960     NaN
# 23998      9            15    37         Mon        2        JAN1960     NaN
# 23999      9            16    37         Tue        3        JAN1960     NaN
#
#       timezone_id   timezone  timezone_offset
# 23995   ETC/GMT+7  GMT-07:00           -25200
# 23996   ETC/GMT+7  GMT-07:00           -25200
# 23997   ETC/GMT+7  GMT-07:00           -25200
# 23998   ETC/GMT+7  GMT-07:00           -25200
# 23999   ETC/GMT+7  GMT-07:00           -25200

# %%
source_date.insert(0, "Date_surrogate_key",  np.arange(len(source_date)))
source_date.head()
# Out:
#        Date_surrogate_key  sasdate  date_key        word_date        date  \
# 21549                   0    21550     10119  January 1, 2019  2019-01-01
# 21550                   1    21551     10219  January 2, 2019  2019-01-02
# 21551                   2    21552     10319  January 3, 2019  2019-01-03
# 21552                   3    21553     10419  January 4, 2019  2019-01-04
# 21553                   4    21554     10519  January 5, 2019  2019-01-05
#
#        year  quarter  month  day_of_month  week day_of_week  weekday  \
# 21549  2019        1      1             1     0         Tue        3
# 21550  2019        1      1             2     0         Wed        4
# 21551  2019        1      1             3     0         Thu        5
# 21552  2019        1      1             4     0         Fri        6
# 21553  2019        1      1             5     0         Sat        7
#
#       month_and_year  holiday timezone_id   timezone  timezone_offset
# 21549        JAN1960  NEWYEAR   ETC/GMT+7  GMT-07:00           -25200
# 21550        JAN1960      NaN   ETC/GMT+7  GMT-07:00           -25200
# 21551        JAN1960      NaN   ETC/GMT+7  GMT-07:00           -25200
# 21552        JAN1960      NaN   ETC/GMT+7  GMT-07:00           -25200
# 21553        JAN1960      NaN   ETC/GMT+7  GMT-07:00           -25200

# %%
csv_result_file_path = 'csv_result_files/'
source_date.to_csv(csv_result_file_path + 'Date_dimension.csv',index=False)
