# %%
import pandas as pd
import numpy as np

# %%
csv_source_file_path = 'csv_source_files\\'
source_cases = pd.read_csv(csv_source_file_path + '455fd63b-603d-4608-8216-7d8647f43350.csv')
source_cases = source_cases[ (source_cases['Specimen_Date']>'2020-10-31') & (source_cases['Specimen_Date']<'2021-03-01') ]
source_cases = source_cases[(source_cases['Reporting_PHU_City']=='Toronto') | 
                            (source_cases['Reporting_PHU_City']=='Ottawa') |
                            (source_cases['Reporting_PHU_City']=='Whitby') |
                            (source_cases['Reporting_PHU_City']=='Oakville') |
                            (source_cases['Reporting_PHU_City']=='Mississauga') |
                            (source_cases['Reporting_PHU_City']=='Newmarket')]

# %%
source_cases.head()
# Out:
#      _id  Row_ID Accurate_Episode_Date   Case_Reported_Date  \
# 418  419     419   2020-12-16T00:00:00  2020-12-17T00:00:00
# 419  420     420   2020-12-15T00:00:00  2020-12-17T00:00:00
# 421  422     422   2020-12-11T00:00:00  2020-12-17T00:00:00
# 422  423     423   2020-12-10T00:00:00  2020-12-17T00:00:00
# 424  425     425   2020-12-15T00:00:00  2020-12-17T00:00:00
#
#       Test_Reported_Date        Specimen_Date Age_Group Client_Gender  \
# 418  2020-12-17T00:00:00  2020-12-16T00:00:00       80s        FEMALE
# 419  2020-12-17T00:00:00  2020-12-15T00:00:00       <20        FEMALE
# 421  2020-12-17T00:00:00  2020-12-16T00:00:00       20s          MALE
# 422  2020-12-17T00:00:00  2020-12-15T00:00:00       30s        FEMALE
# 424  2020-12-17T00:00:00  2020-12-16T00:00:00       30s        FEMALE
#
#     Case_AcquisitionInfo  Outcome1 Outbreak_Related  Reporting_PHU_ID  \
# 418                   CC  Resolved              NaN              2253
# ...

# %%
source_cases["Outbreak_Related"] = source_cases["Outbreak_Related"].map(lambda x: True if (x=="Yes") else False)

#create dimensions
#Patient_dimension = pd.DataFrame(columns=['id','Gender', 'Age_group','Acquisition_group', 'Outbreak_related'])

source_cases = source_cases[['_id','Client_Gender','Age_Group','Case_AcquisitionInfo','Outbreak_Related']]
source_cases = source_cases.rename(columns={'_id': 'id','Client_Gender':'Gender','Case_AcquisitionInfo':'Acquisition_group','Outbreak_Related':'Outbreak_related'})

# %%
source_cases.insert(0,'Patient_key',np.arange(len(source_cases)))
source_cases.head()
# Out:
#      Patient_key   id  Gender Age_Group  Acquisition_group  Outbreak_related
# 418            0  419  FEMALE       80s                 CC             False
# 419            1  420  FEMALE       <20                 CC             False
# 421            2  422    MALE       20s  NO KNOWN EPI LINK             False
# 422            3  423  FEMALE       30s                 CC             False
# 424            4  425  FEMALE       30s                 CC             False

# %%
csv_result_file_path = 'csv_result_files/'
source_cases.to_csv(csv_result_file_path + 'Patient_dimension.csv',index=False)
