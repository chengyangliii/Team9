# %%
import pandas as pd
import numpy as np

# %%
source_PHU = pd.read_csv("conposcovidloc.csv")

# %%
source_PHU = source_PHU[ (source_PHU['Specimen_Date']>'2020-10-31') & (source_PHU['Specimen_Date']<'2021-03-01') ]
#source_PHU = source_PHU[(source_PHU["Reporting_PHU_City"] == 'Toronto')]#| (source_PHU["Reporting_PHU_City"] == 'Ottawa')  | (source_PHU["Reporting_PHU_City"] == 'Whitby') | (source_PHU["Reporting_PHU_City"] == 'Newmarket') | (source_PHU["Reporting_PHU_City"] == 'Oakville')|(source_PHU["Reporting_PHU_City"] == 'Mississauga')]
source_PHU = source_PHU[ (source_PHU['Reporting_PHU_City']=='Toronto') | (source_PHU['Reporting_PHU_City']=='Ottawa') ]

# %%
source_PHU.head()
# Out:
#      Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 627     628            2020-12-16         2020-12-17         2020-12-17
# 630     631            2020-12-16         2020-12-17         2020-12-17
# 795     796            2020-12-16         2020-12-17         2020-12-17
# 796     797            2020-12-16         2020-12-17         2020-12-17
# 990     991            2020-12-16         2020-12-17         2020-12-17
#
#     Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  Outcome1  \
# 627    2020-12-16       40s        FEMALE    NO KNOWN EPI LINK  Resolved
# 630    2020-12-16       <20        FEMALE                   CC  Resolved
# 795    2020-12-16       20s        FEMALE    NO KNOWN EPI LINK  Resolved
# 796    2020-12-16       80s        FEMALE    NO KNOWN EPI LINK  Resolved
# 990    2020-12-16       20s          MALE                   OB  Resolved
#
#     Outbreak_Related  Reporting_PHU_ID          Reporting_PHU  \
# 627              NaN              2251   Ottawa Public Health
# 630              NaN              2251   Ottawa Public Health
# 795              NaN              3895  Toronto Public Health
# 796              NaN              3895  Toronto Public Health
# 990              Yes              2251   Ottawa Public Health
#
#               Reporting_PHU_Address Reporting_PHU_City  \
# 627         100 Constellation Drive             Ottawa
# 630         100 Constellation Drive             Ottawa
# 795  277 Victoria Street, 5th Floor            Toronto
# 796  277 Victoria Street, 5th Floor            Toronto
# 990         100 Constellation Drive             Ottawa
#
#     Reporting_PHU_Postal_Code  \
# 627                   K2G 6J8
# 630                   K2G 6J8
# 795                   M5B 1W2
# 796                   M5B 1W2
# 990                   K2G 6J8
#
#                                  Reporting_PHU_Website  \
# 627                          www.ottawapublichealth.ca
# 630                          www.ottawapublichealth.ca
# 795  www.toronto.ca/community-people/health-wellnes...
# 796  www.toronto.ca/community-people/health-wellnes...
# 990                          www.ottawapublichealth.ca
#
#      Reporting_PHU_Latitude  Reporting_PHU_Longitude
# 627               45.345665               -75.763912
# 630               45.345665               -75.763912
# 795               43.656591               -79.379358
# 796               43.656591               -79.379358
# 990               45.345665               -75.763912

# %%
PHU_Location_dimension = pd.DataFrame(columns=['PHU_Location_key', 
                                               'PHU_name', 'Address', 'City','Postal_Code',
                                               'URL','Latitude','Longitude'])

# %%
source_PHU = source_PHU[['Reporting_PHU_ID','Reporting_PHU','Reporting_PHU_Address','Reporting_PHU_City','Reporting_PHU_Postal_Code','Reporting_PHU_Website','Reporting_PHU_Latitude','Reporting_PHU_Longitude']]
source_PHU = source_PHU.rename(columns={'Reporting_PHU_ID':'ID','Reporting_PHU' : 'PHU_name','Reporting_PHU_Address' : 'Address','Reporting_PHU_City': 'City','Reporting_PHU_Postal_Code' : 'Postal_Code','Reporting_PHU_Website' : 'URL','Reporting_PHU_Latitude' : 'Latitude','Reporting_PHU_Longitude' : 'Longitude'})
source_PHU.insert(5, "Province", 'Ontario', True)

# %%
source_PHU.head()
# Out:
#        ID               PHU_name                         Address     City  \
# 627  2251   Ottawa Public Health         100 Constellation Drive   Ottawa
# 630  2251   Ottawa Public Health         100 Constellation Drive   Ottawa
# 795  3895  Toronto Public Health  277 Victoria Street, 5th Floor  Toronto
# 796  3895  Toronto Public Health  277 Victoria Street, 5th Floor  Toronto
# 990  2251   Ottawa Public Health         100 Constellation Drive   Ottawa
#
#     Postal_Code Province                                                URL  \
# 627     K2G 6J8  Ontario                          www.ottawapublichealth.ca
# 630     K2G 6J8  Ontario                          www.ottawapublichealth.ca
# 795     M5B 1W2  Ontario  www.toronto.ca/community-people/health-wellnes...
# 796     M5B 1W2  Ontario  www.toronto.ca/community-people/health-wellnes...
# 990     K2G 6J8  Ontario                          www.ottawapublichealth.ca
#
#       Latitude  Longitude
# 627  45.345665 -75.763912
# 630  45.345665 -75.763912
# 795  43.656591 -79.379358
# 796  43.656591 -79.379358
# 990  45.345665 -75.763912

# %%
norepeat_df = source_PHU.drop_duplicates(subset=['ID'], keep='first')

# %%
norepeat_df.head()
# Out:
#        ID               PHU_name                         Address     City  \
# 627  2251   Ottawa Public Health         100 Constellation Drive   Ottawa
# 795  3895  Toronto Public Health  277 Victoria Street, 5th Floor  Toronto
#
#     Postal_Code Province                                                URL  \
# 627     K2G 6J8  Ontario                          www.ottawapublichealth.ca
# 795     M5B 1W2  Ontario  www.toronto.ca/community-people/health-wellnes...
#
#       Latitude  Longitude
# 627  45.345665 -75.763912
# 795  43.656591 -79.379358

# %%
norepeat_df.insert(0,'PHU_Location_key',np.arange(len(norepeat_df)))
norepeat_df.head()
# Out:
#      PHU_Location_key    ID               PHU_name  \
# 627                 0  2251   Ottawa Public Health
# 795                 1  3895  Toronto Public Health
#
#                             Address     City Postal_Code Province  \
# 627         100 Constellation Drive   Ottawa     K2G 6J8  Ontario
# 795  277 Victoria Street, 5th Floor  Toronto     M5B 1W2  Ontario
#
#                                                    URL   Latitude  Longitude
# 627                          www.ottawapublichealth.ca  45.345665 -75.763912
# 795  www.toronto.ca/community-people/health-wellnes...  43.656591 -79.379358

# %%
csv_result_file_path = 'csv_result_files\\'
norepeat_df.to_csv(csv_result_file_path + 'PHU_Location_dimension.csv',index=False)
