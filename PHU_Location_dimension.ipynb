# %%
import pandas as pd
import numpy as np

# %%
source_PHU = pd.read_csv("conposcovidloc.csv")

# %%
source_PHU = source_PHU[ (source_PHU['Specimen_Date']>'2020-10-31') & (source_PHU['Specimen_Date']<'2021-03-01') ]
#source_PHU = source_PHU[(source_PHU["Reporting_PHU_City"] == 'Toronto')]#| (source_PHU["Reporting_PHU_City"] == 'Ottawa')  | (source_PHU["Reporting_PHU_City"] == 'Whitby') | (source_PHU["Reporting_PHU_City"] == 'Newmarket') | (source_PHU["Reporting_PHU_City"] == 'Oakville')|(source_PHU["Reporting_PHU_City"] == 'Mississauga')]
source_PHU = source_PHU[ (source_PHU['Reporting_PHU_City']=='Ottawa')| (source_PHU['Reporting_PHU_City']=='Whitby')| (source_PHU['Reporting_PHU_City']=='Newmarket')| (source_PHU['Reporting_PHU_City']=='Oakville')| (source_PHU['Reporting_PHU_City']=='Mississauga') | (source_PHU['Reporting_PHU_City']=='Toronto') ]

# %%
source_PHU.head()
# Out:
#      Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 418     419            2020-12-16         2020-12-17         2020-12-17
# 419     420            2020-12-15         2020-12-17         2020-12-17
# 421     422            2020-12-11         2020-12-17         2020-12-17
# 422     423            2020-12-10         2020-12-17         2020-12-17
# 424     425            2020-12-15         2020-12-17         2020-12-17
#
#     Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  Outcome1  \
# 418    2020-12-16       80s        FEMALE                   CC  Resolved
# 419    2020-12-15       <20        FEMALE                   CC  Resolved
# 421    2020-12-16       20s          MALE    NO KNOWN EPI LINK  Resolved
# 422    2020-12-15       30s        FEMALE                   CC  Resolved
# 424    2020-12-16       30s        FEMALE                   CC  Resolved
#
#     Outbreak_Related  Reporting_PHU_ID                    Reporting_PHU  \
# ...

# %%
PHU_Location_dimension = pd.DataFrame(columns=['PHU_Location_key', 
                                               'PHU_name', 'Address', 'City','Postal_Code',
                                               'URL','Latitude','Longitude'])

# %%
source_PHU = source_PHU[['Reporting_PHU_ID','Reporting_PHU','Reporting_PHU_Address','Reporting_PHU_City','Reporting_PHU_Postal_Code','Reporting_PHU_Website','Reporting_PHU_Latitude','Reporting_PHU_Longitude']]
source_PHU = source_PHU.rename(columns={'Reporting_PHU_ID':'ID','Reporting_PHU' : 'PHU_name','Reporting_PHU_Address' : 'Address','Reporting_PHU_City': 'City','Reporting_PHU_Postal_Code' : 'Postal_Code','Reporting_PHU_Website' : 'URL','Reporting_PHU_Latitude' : 'Latitude','Reporting_PHU_Longitude' : 'Longitude'})
source_PHU.insert(5, "Province", 'Ontario', True)

# %%
source_PHU.head()
# Out:
#        ID                         PHU_name                 Address  \
# 418  2253               Peel Public Health  7120 Hurontario Street
# 419  2253               Peel Public Health  7120 Hurontario Street
# 421  2253               Peel Public Health  7120 Hurontario Street
# 422  2253               Peel Public Health  7120 Hurontario Street
# 424  2236  Halton Region Health Department        1151 Bronte Road
#
#             City Postal_Code Province  \
# 418  Mississauga     L5W 1N4  Ontario
# 419  Mississauga     L5W 1N4  Ontario
# 421  Mississauga     L5W 1N4  Ontario
# 422  Mississauga     L5W 1N4  Ontario
# 424     Oakville     L6M 3Ll  Ontario
#
#                                              URL   Latitude  Longitude
# 418                    www.peelregion.ca/health/  43.647471 -79.708893
# 419                    www.peelregion.ca/health/  43.647471 -79.708893
# 421                    www.peelregion.ca/health/  43.647471 -79.708893
# ...

# %%
norepeat_df = source_PHU.drop_duplicates(subset=['ID'], keep='first')

# %%
norepeat_df.head()
# Out:
#        ID                            PHU_name                  Address  \
# 418  2253                  Peel Public Health   7120 Hurontario Street
# 424  2236     Halton Region Health Department         1151 Bronte Road
# 434  2270  York Region Public Health Services       17250 Yonge Street
# 600  2230     Durham Region Health Department   605 Rossland Road East
# 627  2251                Ottawa Public Health  100 Constellation Drive
#
#             City Postal_Code Province  \
# 418  Mississauga     L5W 1N4  Ontario
# 424     Oakville     L6M 3Ll  Ontario
# 434    Newmarket     L3Y 6Z1  Ontario
# 600       Whitby     L1N 0B2  Ontario
# 627       Ottawa     K2G 6J8  Ontario
#
#                                                    URL   Latitude  Longitude
# 418                          www.peelregion.ca/health/  43.647471 -79.708893
# 424        www.halton.ca/For-Residents/Public-Health/   43.413997 -79.744796
# ...

# %%
norepeat_df.insert(0,'PHU_Location_key',np.arange(len(norepeat_df)))
norepeat_df.head()
# Out:
#      PHU_Location_key    ID                            PHU_name  \
# 418                 0  2253                  Peel Public Health
# 424                 1  2236     Halton Region Health Department
# 434                 2  2270  York Region Public Health Services
# 600                 3  2230     Durham Region Health Department
# 627                 4  2251                Ottawa Public Health
#
#                      Address         City Postal_Code Province  \
# 418   7120 Hurontario Street  Mississauga     L5W 1N4  Ontario
# 424         1151 Bronte Road     Oakville     L6M 3Ll  Ontario
# 434       17250 Yonge Street    Newmarket     L3Y 6Z1  Ontario
# 600   605 Rossland Road East       Whitby     L1N 0B2  Ontario
# 627  100 Constellation Drive       Ottawa     K2G 6J8  Ontario
#
#                                                    URL   Latitude  Longitude
# 418                          www.peelregion.ca/health/  43.647471 -79.708893
# ...

# %%
csv_result_file_path = 'csv_result_files\\'
norepeat_df.to_csv(csv_result_file_path + 'PHU_Location_dimension.csv',index=False)
